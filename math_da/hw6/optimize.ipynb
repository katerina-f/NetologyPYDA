# %%
import numpy as np
from scipy.optimize import differential_evolution
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Задание
# При фиксированном seed=42 поразбирайтесь и поэкспериментируйте с параметрами алгоритма дифференциальной эволюции: strategy, popsize, tol, mutation, recombination и updating.
#
# Постройте графики количества итераций оптимизации функции ackley от значения параметра.

# %%
def ackley(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

bounds = [(-10, 10), (-10, 10)]
result = differential_evolution(ackley, bounds, seed=42)
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 2793
#      nit: 90
#  success: True
#        x: array([0., 0.])

# %%
def draw_graph(title, x, y, x_label):
    plt.plot(x1, y1, '-o')
    plt.title(title)
    plt.ylabel("nit")
    plt.xlabel(x_label)
    plt.show()

# %%
def change_popsize_with_maxiter(x):
    return differential_evolution(ackley, bounds, seed=42, popsize=x, maxiter=50)
    
x1 = np.arange(1, 100, 10)
y1 = [change_popsize_with_maxiter(i).nit for i in range(len(x1))]

draw_graph('График количества итераций от параметра posize и maxiter = 50', x1, y1, "popsize")

# %%
def change_popsize(x):
    return differential_evolution(ackley, bounds, seed=42, popsize=x)
    
x1 = np.arange(1, 100, 10)
y1 = [change_popsize(i).nit for i in range(len(x1))]

draw_graph('График количества итераций от параметра popsize (размер популяции)', x1, y1, "popsize")

# %%
def change_popsize_with_randtobest1bin(x):
    return differential_evolution(ackley, bounds, seed=42, strategy="randtobest1bin", popsize=x)
    
x1 = np.arange(1, 100, 10)
y1 = [change_popsize_with_randtobest1bin(i).nit for i in range(len(x1))]

draw_graph('График количества итераций от параметра popsize (размер популяции) при стратегии randtobest1bin', x1, y1, "popsize")

# %%
def change_popsize_with_best2exp(x):
    return differential_evolution(ackley, bounds, seed=42, strategy="best2exp", popsize=x)
    
x1 = np.arange(1, 100, 10)
y1 = [change_popsize_with_best2exp(i).nit for i in range(len(x1))]

draw_graph('График количества итераций от параметра popsize (размер популяции) при стратегии best2exp', x1, y1, "popsize")

# %%
def change_mutation(x):
    return differential_evolution(ackley, bounds, seed=42, mutation=x)
    
x1 = np.linspace(0.1, 1.9, 10, dtype=float)
y1 = [change_mutation(i).nit for i in x1]

draw_graph('График количества итераций от параметра mutation (размер популяции)', x1, y1, "mutation")

# %%
def change_tol(x):
    return differential_evolution(ackley, bounds, seed=42, tol=x)
    
x1 = np.linspace(0.1, 1.9, 10, dtype=float)
y1 = [change_tol(i).nit for i in x1]

draw_graph('График количества итераций от параметра tol', x1, y1, "tol")

# %%
def change_recombination(x):
    return differential_evolution(ackley, bounds, seed=42, recombination=x)
    
x1 = np.linspace(0.1, 1.0, 10, dtype=float)
y1 = [change_recombination(i).nit for i in x1]

draw_graph('График количества итераций от параметра recombination', x1, y1, "recombination")

# %%
def change_mutation_with_updating(x):
    return differential_evolution(ackley, bounds, seed=42, mutation=x, updating="immediate")
    
x1 = np.linspace(0.1, 1.9, 10, dtype=float)
y1 = [change_mutation_with_updating(i).nit for i in x1]

draw_graph('График количества итераций от параметра mutation при updating = immediate', x1, y1, "mutation")
